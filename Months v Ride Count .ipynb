# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("Resources of CSV files/MonthlyWeatherBostonMerged.csv")
df2 = pd.read_csv("Resources of CSV files/MonthlyWeatherPortlandMerged.csv")

# %%
df1.head()
# Out:
#     dt_iso  city_id     pressure   humidity  wind_speed  avg_temp_f  \
# 0  2018-01  4930956  1019.879032  68.669355    3.809140   27.742851
# 1  2018-02  4930956  1022.410714  73.870536    3.300595   37.200688
# 2  2018-03  4930956  1011.817204  66.274194    4.239247   36.688460
# 3  2018-04  4930956  1015.209722  66.344444    3.493056   44.482076
# 4  2018-05  4930956  1017.379032  73.413978    2.989247   61.445757
#
#    weather_type  Average Trip Duration  Amount of Rides  Subscribers  \
# 0           1.0              16.191401          45328.0      43796.0
# 1           1.0              16.112764          64136.0      60495.0
# 2           1.0              16.942872          70578.0      65248.0
# 3           1.0              27.884957         114995.0      98469.0
# 4           1.0              41.816718         174273.0     140472.0
#
#    Non Subscribers  Subscriber %  Non Subscriber %
# 0           1532.0          97.0               3.0
# 1           3641.0          94.0               6.0
# 2           5330.0          92.0               8.0
# 3          16526.0          86.0              14.0
# 4          33801.0          81.0              19.0

# %%
dateindex=df1['dt_iso']
x = df1['dt_iso']
aa=dict(zip(x,df1['Amount of Rides']))
bb=dict(zip(x,df2['Amount of Rides']))
bars = ('Jan', 'Feb', 'Mar', 'Apr', 'Mar', 'Jun', 'Jul','Aug','Sep','Oct','Nov','Dec')


dfbar = pd.DataFrame({'Boston': aa, 'Portland': bb}, index=dateindex)

# Non-stacked bar plot
dfbar.plot.bar(figsize=(10, 9))

plt.title("Rides per Month")
plt.legend(title="City")
plt.xlabel('Months')
plt.ylabel('Rides')
plt.xticks(np.arange(12), bars)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.savefig("Output/Rides_per_Month.png")
