# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Resources of CSV files/MonthlyWeatherPortlandMerged.csv")

# %%
x_axis = np.arange(len(df))
tick_locations = [value+0.4 for value in x_axis] 
plt.bar(x_axis, df["avg_temp_f"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, df["dt_iso"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x11d710470>,
# ...
#  <a list of 12 Text xticklabel objects>)
