# %%
import pandas as pd

# %%
jan = "Resources/Jan-NY.csv"
feb = "Resources/Feb-NY.csv"
mar = "Resources/Mar-NY.csv"
apr = "Resources/Apr-NY.csv"
may = "Resources/May-NY.csv"
jun = "Resources/Jun-NY.csv"
jul = "Resources/Jul-NY.csv"
aug = "Resources/Aug-NY.csv"
sep = "Resources/Sep-NY.csv"
oct = "Resources/Oct-NY.csv"
nov = "Resources/Nov-NY.csv"
dec = "Resources/Dec-NY.csv"
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
jan_df = pd.read_csv(jan)

new_jan = jan_df[['tripduration', 'starttime', 'stoptime','usertype', 'birth year']]

newer_jan = new_jan.dropna()
newerer_jan = newer_jan.rename(columns={'tripduration': 'Trip Duration',
                                        'starttime': 'Start Time',
                                        'stoptime': 'Stop Time',
                                        'usertype': 'User Type',
                                        'birth year': 'Birth Year'})
newerer_jan['Age'] = 2019 - (newerer_jan['Birth Year'])

newest_jan = newerer_jan.drop(columns=['Birth Year'])

newest_jan.head()
# Out:
#    Trip Duration                Start Time                 Stop Time  \
# 0            970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1            723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2            496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3            306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4            306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#     User Type  Age
# 0  Subscriber   27
# 1  Subscriber   50
# 2  Subscriber   63
# 3  Subscriber   45
# 4  Subscriber   27
