# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
bos = "DailyWeatherBostonMerged.csv"
port = "DailyWeatherPortlandMerged.csv"

# %%
bos_df = pd.read_csv(bos)
port_df = pd.read_csv(port)

# %%
bos_df.head()
# Out:
#        dt_iso  city_id     pressure   humidity  wind_speed  avg_temp_f  \
# 0  2018-01-01  4930956  1023.000000  55.041667    5.000000    4.479498
# 1  2018-01-02  4930956  1024.375000  59.875000    3.625000    6.002750
# 2  2018-01-03  4930956  1023.458333  63.333333    2.416667   17.818248
# 3  2018-01-04  4930956  1003.666667  79.375000    5.625000   22.721750
# 4  2018-01-05  4930956   992.833333  59.333333    7.625000   17.933748
#
#   weather_type  Average Trip Duration  Amount of Rides  Subscribers  \
# 0          1.0              12.724726            175.0        173.0
# 1          1.0              13.320548            757.0        741.0
# 2          1.0              15.045657           1302.0       1277.0
# 3          8.0              32.958472            188.0        188.0
# 4          8.0              14.736448            198.0        196.0
#
#    Non Subscribers  Subscriber %  Non Subscriber %
# 0              2.0          99.0               1.0
# ...

# %%
ax = plt.gca()

#bos_df.plot(kind='line',x='dt_iso',y='Amount of Riders',ax=ax)
bos_df.plot(kind='line',x='dt_iso',y='avg_temp_f', color='red', ax=ax)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
port_df.head()
# Out:
#        dt_iso  city_id     pressure   humidity  wind_speed  avg_temp_f  \
# 0  2018-01-01  4975802  1020.166667  53.375000    3.375000   -3.625754
# 1  2018-01-02  4975802  1021.958333  53.458333    3.041667   -1.625498
# 2  2018-01-03  4975802  1021.833333  66.000000    3.166667    8.669752
# 3  2018-01-04  4975802  1005.666667  82.083333    5.291667   14.626246
# 4  2018-01-05  4975802   988.041667  65.333333    7.583333   15.682999
#
#   weather_type  Average Trip Duration  Amount of Rides  Subscribers  \
# 0            1              21.510134            318.0        174.0
# 1            1              15.159443            350.0        282.0
# 2            1              18.493613            393.0        283.0
# 3            8              16.217457            394.0        338.0
# 4            8              19.517305            346.0        265.0
#
#    Non Subscribers  Subscriber %  Non Subscriber %
# 0            144.0          55.0              45.0
# ...
