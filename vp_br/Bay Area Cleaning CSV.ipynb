# %%
import pandas as pd

# %%
jan = "Resources/2018-01.csv"
feb = "Resources/201802-fordgobike-tripdata.csv"
mar = "Resources/201803-fordgobike-tripdata.csv"
apr = "Resources/201804-fordgobike-tripdata.csv"
may = "Resources/201805-fordgobike-tripdata.csv"
jun = "Resources/201806-fordgobike-tripdata.csv"
jul = "Resources/201807-fordgobike-tripdata.csv"
aug = "Resources/201808-fordgobike-tripdata.csv"
sept ="Resources/201809-fordgobike-tripdata.csv"
octo = "Resources/201810-fordgobike-tripdata.csv"
nov = "Resources/201811-fordgobike-tripdata.csv"
dec = "Resources/201812-fordgobike-tripdata.csv"

# %%
jan_df = pd.read_csv(jan)
jan_df
# Out:
#        duration_sec start_time end_time  start_station_id  \
# 0             75284    52:35.2  47:19.8               120
# 1             85422    13:34.4  57:17.3                15
# 2             71576    23:55.9  16:52.1               304
# 3             61076    53:23.6  51:20.5                75
# 4             39966    52:24.7  58:31.1                74
# 5              6477    58:44.9  46:41.9               236
# 6               453    53:53.6  01:26.8               110
# 7               180    52:09.9  55:10.8                81
# 8               996    34:56.0  51:32.7               134
# 9               825    34:14.0  47:59.8               305
# 10             1316    24:00.4  45:56.8                98
# 11              432    34:26.5  41:39.3                89
# 12              601    29:46.8  39:48.0               223
# 13              887    24:16.4  39:04.1               308
# 14              210    33:03.0  36:33.7                 7
# ...

# %%
new_jan = jan_df[['duration_sec', 'start_time', 
                        'end_time', 'user_type', 
                        'member_birth_year', 'member_gender']]
final_jan = new_jan.dropna()
renamed_jan = final_jan.rename(columns={'duration_sec': 'Trip Duration', 'start_time': 'Start Time', 
                        'end_time': 'Stop Time', 'user_type': 'User Type', 
                        'member_birth_year': 'Age', 'member_gender': 'Gender'})
renamed_jan['Age'] = 2018 - (renamed_jan['Age'])
#renamed_jan['Gender'] = renamed_jan['Gender'].replace([0,1,2],['Female','Male','Other'])
renamed_jan.head()
# Out:
#    Trip Duration Start Time Stop Time   User Type   Age Gender
# 0          75284    52:35.2   47:19.8  Subscriber  32.0   Male
# 2          71576    23:55.9   16:52.1    Customer  22.0   Male
# 4          39966    52:24.7   58:31.1  Subscriber  27.0   Male
# 6            453    53:53.6   01:26.8  Subscriber  30.0   Male
# 7            180    52:09.9   55:10.8  Subscriber  38.0   Male
